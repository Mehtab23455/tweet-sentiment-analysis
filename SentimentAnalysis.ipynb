# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
import re
import nltk
from nltk.corpus import stopwords

# %%
df = pd.read_csv("/content/drive/MyDrive/Tweets.csv")

# %%
df.head()
# Out:
#              tweet_id  ...               user_timezone
# 0  570306133677760513  ...  Eastern Time (US & Canada)
# 1  570301130888122368  ...  Pacific Time (US & Canada)
# 2  570301083672813571  ...  Central Time (US & Canada)
# 3  570301031407624196  ...  Pacific Time (US & Canada)
# 4  570300817074462722  ...  Pacific Time (US & Canada)
#
# [5 rows x 15 columns]

# %%
df.shape
# Out:
# (14640, 15)

# %%
df.isnull()
# Out:
#        tweet_id  airline_sentiment  ...  tweet_location  user_timezone
# 0         False              False  ...            True          False
# 1         False              False  ...            True          False
# 2         False              False  ...           False          False
# 3         False              False  ...            True          False
# 4         False              False  ...            True          False
# ...         ...                ...  ...             ...            ...
# 14635     False              False  ...            True           True
# 14636     False              False  ...           False           True
# 14637     False              False  ...           False           True
# 14638     False              False  ...           False          False
# 14639     False              False  ...           False           True
#
# [14640 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# tweet_id                            0
# airline_sentiment                   0
# airline_sentiment_confidence        0
# negativereason                   5462
# negativereason_confidence        4118
# airline                             0
# airline_sentiment_gold          14600
# name                                0
# negativereason_gold             14608
# retweet_count                       0
# text                                0
# tweet_coord                     13621
# tweet_created                       0
# tweet_location                   4733
# user_timezone                    4820
# dtype: int64

# %%
df = df.drop(['airline_sentiment_confidence','negativereason','negativereason_confidence','airline_sentiment_gold','name','negativereason_gold','retweet_count','tweet_coord','tweet_created','tweet_location','user_timezone'],axis=1)

# %%
df.head(3)
# Out:
#   airline_sentiment  ...                                               text
# 0           neutral  ...                @VirginAmerica What @dhepburn said.
# 1          positive  ...  @VirginAmerica plus you've added commercials t...
# 2           neutral  ...  @VirginAmerica I didn't today... Must mean I n...
#
# [3 rows x 3 columns]

# %%
#Downloading stopwords from nl toolkit
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#creating a preprocessing function
def preprocess(text):

    text = text.lower()
    text = re.sub(r"http\S+|www.\S+", "", text)
    text = re.sub(r"@\w+|#\w+", "", text)
    text = re.sub(r"[^\w\s]", "", text)
    text = re.sub(r"\d+", "", text)
    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]
    return " ".join(tokens)

df['clean_text'] = df['text'].apply(preprocess)

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

texts = df['clean_text']


count_vectorizer = CountVectorizer()
X_bow = count_vectorizer.fit_transform(df['clean_text'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score


X_train, X_test, y_train, y_test = train_test_split(X_bow, df['airline_sentiment'], test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score


model = LogisticRegression(max_iter=1000)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array(['positive', 'negative', 'negative', ..., 'negative', 'neutral',
#        'negative'], dtype=object)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.79474043715847
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.89      0.87      1889
#      neutral       0.61      0.57      0.59       580
#     positive       0.75      0.69      0.72       459
#
#     accuracy                           0.79      2928
#    macro avg       0.74      0.72      0.73      2928
# weighted avg       0.79      0.79      0.79      2928

# %%
df.text[23]
# Out:
# '@VirginAmerica will you be making BOS&gt;LAS non stop permanently anytime soon?'

# %%
print(y_pred[23])
# Out:
# negative

# %%
# !git clone https://github.com/Mehtab23455/tweet-sentiment-analysis
# Out:
# Cloning into 'tweet-sentiment-analysis'...
# ...

# %%
# %cd tweet-sentiment-analysis
# Out:
# /content/tweet-sentiment-analysis

# %%
# !git add .

# %%
# !git commit -m "Initial commit with sentiment analysis model"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@8b6d7de02621.(none)')

# %%
# !git clone https://github.com/Mehtab23455/tweet-sentiment-analysis
# %cd /https://github.com/Mehtab23455/tweet-sentiment-analysis
# !git checkout -b main
# Out:
# Cloning into 'tweet-sentiment-analysis'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# [Errno 2] No such file or directory: '/https://github.com/Mehtab23455/tweet-sentiment-analysis'
# /content/tweet-sentiment-analysis
# Switched to a new branch 'main'

# %%
# !cp /content/SentimentAnalysis.ipynb /content/github.com/Mehtab23455/tweet-sentiment-analysis/
# Out:
# cp: cannot stat '/content/SentimentAnalysis.ipynb': No such file or directory

# %%
# !git add .
# !git commit -m "Add "
# !git push origin main
# Out:
# ...
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> tweet-sentiment-analysis
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached tweet-sentiment-analysis
# hint:
# hint: See "git help submodule" for more information.
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@8b6d7de02621.(none)')
# error: src refspec main does not match any
# ...
